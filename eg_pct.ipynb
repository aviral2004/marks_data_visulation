# %%
import matplotlib.pyplot as plt
import pandas as pd
from scipy import stats

import seaborn as sns
sns.set_theme()

df = pd.read_csv('./data/EG_PCT.csv')

df.rename(columns={'Pre-compre(120)':'Marks'}, inplace=True)
df.rename(columns={'ID NO':'ID'}, inplace=True)
df['code'] = df['ID'].str[4:6]

# drop rows with all any NaN values
df.dropna(axis=0, how='any', inplace=True)

# %load_ext autoreload
# %autoreload 2

df
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
#                 ID  Eval (Best6) (50)  Midsem(70)  Marks code
# 1    2022A8PS1240P               42.2        47.5   89.7   A8
# 2    2022A3PS0412P               47.8        41.0   88.8   A3
# 3    2022A4PS0831P               41.9        49.5   91.4   A4
# 4    2022A7PS0012P               46.9        22.0   68.9   A7
# 5    2022A1PS1572P               49.4        48.0   97.4   A1
# ..             ...                ...         ...    ...  ...
# 575  2022A3PS1197P               42.2        20.0   62.2   A3
# 576  2022A3PS1216P               46.7        53.5  100.2   A3
# 577  2022A1PS1328P               49.4        22.0   71.4   A1
# 578  2022A4PS1563P               49.7        55.0  104.7   A4
# 579  2022A1PS1573P               39.7        22.0   61.7   A1
#
# [566 rows x 5 columns]

# %%
from graph_gen import graph

g = graph('EG PCT', df, 120, codes=True)
g.gen_all()

# %%
# print out mean, top 10 percentile and top 25 percentile and highest marks
print('Highest: ', df['Marks'].max())
print('Mean: ', df['Marks'].mean())
print('Top 10 percentile: ', df['Marks'].quantile(0.9))
print('Top 25 percentile: ', df['Marks'].quantile(0.75))
# Out:
# Highest:  118.0
# Mean:  79.18021201413427
# Top 10 percentile:  103.95
# Top 25 percentile:  94.425

# %%
max_marks = 120

# %%
g.gen_hist(hist_ticks=5)
