# %%
import matplotlib.pyplot as plt
import pandas as pd
from scipy import stats

import seaborn as sns
sns.set_theme()

df = pd.read_csv('./data/chem_total.csv')

# remove all rows with nans
df = df.dropna()

df.rename(columns={'Total':'Marks'}, inplace=True)
df.rename(columns={'ID NO':'ID'}, inplace=True)

# %load_ext autoreload
# %autoreload 2

df
# Out:
#                 ID    Q1    Q2    Q3    Q4  Best 3  Midsem    PCT    CB    OB  \
# 0    2022A1PS0530P  21.5  13.0   5.5  14.5    49.0    21.5   70.5   5.0  10.5
# 1    2022A1PS0589P  25.0  21.5  22.0  15.0    68.5    37.5  106.0  17.5  21.5
# 2    2022A1PS0593P  25.0  16.5  19.0   9.0    60.5    37.0   97.5   6.5  13.5
# 3    2022A1PS0643P  19.5  17.5  12.0  15.5    52.5    24.5   77.0  18.0  11.0
# 4    2022A1PS0661P   0.0   0.0   4.5   2.5     7.0    11.5   18.5   6.5   9.0
# ..             ...   ...   ...   ...   ...     ...     ...    ...   ...   ...
# 573  2022AAPS0363P  20.0  13.0  20.5   9.0    53.5    34.0   87.5  15.0  27.5
# 574  2022AAPS0366P  25.5  25.5  18.0  15.5    69.0    40.0  109.0   7.0  25.0
# 575  2022AAPS0369P  21.5  22.0  13.0  14.0    57.5    26.0   83.5  11.5  24.5
# 576  2022AAPS1191P  22.5  14.0  19.0  12.5    55.5    32.5   88.0   5.5  17.5
# 577  2022AAPS1192P  27.0  13.0  15.5  18.0    60.5    44.5  105.0  16.5  34.5
#
#      C_Total  Marks
# 0       15.5   86.0
# 1       39.0  145.0
# 2       20.0  117.5
# 3       29.0  106.0
# 4       15.5   34.0
# ..       ...    ...
# 573     42.5  130.0
# 574     32.0  141.0
# 575     36.0  119.5
# 576     23.0  111.0
# 577     51.0  156.0
#
# [578 rows x 12 columns]

# %%
from graph_gen import graph

g = graph('Chem Total', df, 300)
g.gen_all()
