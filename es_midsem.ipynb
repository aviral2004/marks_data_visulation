# %%
import matplotlib.pyplot as plt
import pandas as pd
from scipy import stats

df = pd.read_csv('./data/es_midsem.csv',on_bad_lines='skip')

df.rename(columns={'Mid-Sem':'Marks'}, inplace=True)
df.rename(columns={'ID NO':'ID No'}, inplace=True)

df['Marks'] = pd.to_numeric(df['Marks'], errors='coerce').fillna(0)
df['Quiz1'] = pd.to_numeric(df['Quiz1'], errors='coerce').fillna(0)
df['Quiz2'] = pd.to_numeric(df['Quiz2'], errors='coerce').fillna(0)

df['code'] = df['ID No'].str[4:6]

df
# Out:
#              ID No                       Name  Quiz1  Quiz2  Marks  Total code
# 0    2020B5PS2011P            Jaanavi Chaubey   12.0    0.0    4.0   16.0   B5
# 1    2021D2TS2075P               MS. JAYSHREE    0.0    1.5    0.0    1.5   D2
# 2    2022A1PS0530P                  IRA DOGRA    0.0    0.0   14.0   14.0   A1
# 3    2022A1PS0589P            ASLESH JAMBHALE   13.0   11.0   43.0   67.0   A1
# 4    2022A1PS0593P  AAYUSH AASHISH MAHESHWARI    6.0    5.0   25.0   36.0   A1
# ..             ...                        ...    ...    ...    ...    ...  ...
# 571  2022AAPS0363P             NISHKARSH JAIN   12.0   13.0   51.0   76.0   AA
# 572  2022AAPS0366P             DIWAKAR MITTAL    8.0    5.0   28.0   41.0   AA
# 573  2022AAPS0369P                 SUBRAT ROY   12.0   12.0   33.0   57.0   AA
# 574  2022AAPS1191P     SHAILENDRA KUMAR GUPTA    8.0   13.0   20.0   41.0   AA
# 575  2022AAPS1192P            KUSHAAGRA SINGH   15.0    0.0   65.0   80.0   AA
#
# [576 rows x 7 columns]

# %%
max_marks = 105

# %%
import seaborn as sns
sns.set_theme()

df.hist(column='Marks',bins=max_marks, grid=False, figsize=(12,8), color='#86bf91', zorder=2, rwidth=0.9)
plt.xlabel('Marks')
plt.ylabel('Frequency')
plt.title('Marks Distribution for ES Midsem')
# Out:
# Text(0.5, 1.0, 'Marks Distribution for ES Midsem')

# %%
print(f"Mean: {df['Marks'].mean()}")
print(f"Median: {df['Marks'].median()}")
# Out:
# Mean: 32.71527777777778
# Median: 30.0

# %%
for i in range(80, 160):
    print(f"marks: {i/2} -> {stats.percentileofscore(df['Marks'], i/2, kind='weak')}")
# Out:
# marks: 40.0 -> 66.84027777777777
# marks: 40.5 -> 66.84027777777777
# marks: 41.0 -> 67.88194444444444
# marks: 41.5 -> 67.88194444444444
# marks: 42.0 -> 69.44444444444444
# marks: 42.5 -> 69.44444444444444
# marks: 43.0 -> 70.48611111111111
# marks: 43.5 -> 70.48611111111111
# marks: 44.0 -> 72.04861111111111
# marks: 44.5 -> 72.04861111111111
# marks: 45.0 -> 72.56944444444444
# marks: 45.5 -> 72.56944444444444
# marks: 46.0 -> 73.78472222222221
# marks: 46.5 -> 73.78472222222221
# marks: 47.0 -> 75.0
# marks: 47.5 -> 75.0
# marks: 48.0 -> 76.21527777777777
# marks: 48.5 -> 76.21527777777777
# marks: 49.0 -> 76.90972222222221
# marks: 49.5 -> 76.90972222222221
# marks: 50.0 -> 77.25694444444444
# marks: 50.5 -> 77.25694444444444
# marks: 51.0 -> 77.95138888888889
# marks: 51.5 -> 77.95138888888889
# marks: 52.0 -> 78.125
# marks: 52.5 -> 78.125
# marks: 53.0 -> 78.64583333333333
# marks: 53.5 -> 78.64583333333333
# marks: 54.0 -> 79.51388888888889
# marks: 54.5 -> 79.51388888888889
# marks: 55.0 -> 80.20833333333333
# marks: 55.5 -> 80.20833333333333
# marks: 56.0 -> 80.72916666666666
# marks: 56.5 -> 80.72916666666666
# marks: 57.0 -> 81.59722222222221
# marks: 57.5 -> 81.59722222222221
# marks: 58.0 -> 82.63888888888889
# marks: 58.5 -> 82.63888888888889
# marks: 59.0 -> 82.98611111111111
# marks: 59.5 -> 82.98611111111111
# marks: 60.0 -> 84.375
# marks: 60.5 -> 84.375
# marks: 61.0 -> 85.59027777777777
# marks: 61.5 -> 85.59027777777777
# marks: 62.0 -> 86.45833333333333
# marks: 62.5 -> 86.45833333333333
# marks: 63.0 -> 86.97916666666666
# marks: 63.5 -> 86.97916666666666
# marks: 64.0 -> 87.32638888888889
# marks: 64.5 -> 87.32638888888889
# marks: 65.0 -> 88.02083333333333
# marks: 65.5 -> 88.02083333333333
# marks: 66.0 -> 89.0625
# marks: 66.5 -> 89.0625
# marks: 67.0 -> 89.75694444444444
# marks: 67.5 -> 89.75694444444444
# marks: 68.0 -> 90.625
# marks: 68.5 -> 90.625
# marks: 69.0 -> 91.14583333333333
# marks: 69.5 -> 91.14583333333333
# marks: 70.0 -> 91.84027777777777
# marks: 70.5 -> 91.84027777777777
# marks: 71.0 -> 92.88194444444444
# marks: 71.5 -> 92.88194444444444
# marks: 72.0 -> 93.40277777777777
# marks: 72.5 -> 93.40277777777777
# marks: 73.0 -> 93.75
# marks: 73.5 -> 93.75
# marks: 74.0 -> 93.75
# marks: 74.5 -> 93.75
# marks: 75.0 -> 94.09722222222221
# marks: 75.5 -> 94.09722222222221
# marks: 76.0 -> 94.44444444444444
# marks: 76.5 -> 94.44444444444444
# marks: 77.0 -> 95.13888888888889
# marks: 77.5 -> 95.13888888888889
# marks: 78.0 -> 95.83333333333333
# marks: 78.5 -> 95.83333333333333
# marks: 79.0 -> 96.52777777777777
# marks: 79.5 -> 96.52777777777777

# %%
fig, ax = plt.subplots(figsize = (6,4))
df['Marks'].plot(kind = "hist", density=True, bins=max_marks, grid=False, figsize=(12,8), color='#86bf91', zorder=2, rwidth=0.9)
df['Marks'].plot(kind = "kde", ax=ax)
ax.set_xlim(0, max_marks)
plt.show()

# %%
a7_df = df[df['code'] == 'A7']
a7_df
# Out:
#              ID No                     Name  Quiz1  Quiz2  Marks  Total code
# 296  2022A7PS0001P            KALPANA PANDA    0.0    7.0   19.0   26.0   A7
# 297  2022A7PS0003P     SIDDARTH RAJAGOPALAN   10.0   13.0   97.0  120.0   A7
# 298  2022A7PS0004P               DEEPAN ROY    0.0    0.0   30.0   30.0   A7
# 299  2022A7PS0005P      DEVANSH NIKHIL SHAH    6.0    6.0    7.0   19.0   A7
# 300  2022A7PS0006P       AISHNA SHRIVASTAVA    7.0   15.0   54.0   76.0   A7
# ..             ...                      ...    ...    ...    ...    ...  ...
# 449  2022A7PS1186P             SHASHANK JHA    3.0    6.0   71.0   80.0   A7
# 450  2022A7PS1187P    HARSIMAR SINGH SALUJA   15.0   12.0   37.0   64.0   A7
# 451  2022A7PS1188P             ARMAAN SETHI    6.0   15.0   48.0   69.0   A7
# 452  2022A7PS1189P              ARNAV GUPTA   15.0   15.0   34.0   64.0   A7
# 453  2022A7PS1733P  PRATHAM PRATEEK MOHANTY    7.0    6.0   44.0   57.0   A7
#
# [158 rows x 7 columns]

# %%
a7_df.hist(column='Marks',bins=max_marks, grid=False, figsize=(12,8), color='#86bf91', zorder=2, rwidth=0.9)
# label x and y axes
plt.xlabel('Marks')
plt.ylabel('Frequency')
# set title
plt.title('A7 Marks Histogram')
# Out:
# Text(0.5, 1.0, 'A7 Marks Histogram')

# %%
for i in range(40, 75):
    print(f"marks: {i} -> {stats.percentileofscore(a7_df['Marks'], i, kind='weak')}")

# %%
print(a7_df['Marks'].mean())
print(a7_df['Marks'].median())
# Out:
# 39.120253164556964
# 40.5

# %%
fig, ax = plt.subplots(figsize = (6,4))
df['Marks'].plot(kind = "hist", bins=max_marks, range=[0,max_marks], grid=False, figsize=(12,8), zorder=2, rwidth=0.9)
a7_df['Marks'].plot(kind = "hist", bins=max_marks, range=[0,max_marks], grid=False, figsize=(12,8), zorder=2, rwidth=0.9, label='A7')
df[df['code'] == 'AA']['Marks'].plot(kind = "hist", bins=max_marks, range=[0,max_marks], grid=False, figsize=(12,8), zorder=2, rwidth=0.9, label='AA')
ax.set_xlim(0, max_marks)
plt.legend()
plt.show()

# %%
fig, ax = plt.subplots(figsize = (10, 7))

sns.boxplot(x="code", y="Marks", data=df, ax=ax, palette="rainbow")
# add a horizontal line at the mean
plt.axhline(df['Marks'].mean(), color='r', linestyle='dashed', linewidth=2)

# %%
import matplotlib.ticker as ticker

fig, ax = plt.subplots(figsize = (10,4))
fun = lambda k: [i/k for i in list(range(1, max_marks*k + 1))]

a = fun(2)
b = [stats.percentileofscore(df["Marks"],i, kind='weak') for i in a]
ax.plot(a, b)

lis = [i for i in range(0, 101)]

plt.axvline(x=df['Marks'].quantile([0.5]).values[0], color='pink', linestyle='--', label='50th percentile')
plt.axvline(x=df['Marks'].quantile([0.9]).values[0], color='red', linestyle='--', label='90th percentile')
plt.axvline(x=df['Marks'].quantile([0.75]).values[0], color='green', linestyle='--', label='75th percentile')
plt.axvline(x=df['Marks'].quantile([0.8]).values[0], color='yellow', linestyle='--', label='80th percentile')



ax.xaxis.set_major_locator(ticker.MultipleLocator(25))
ax.set_ylim(0,101)
ax.set_xlim(0,max_marks)
ax.set_xlabel("Marks")
ax.set_ylabel("Percentile")
ax.legend()
plt.title('Percentile for ES Midsem')
plt.show()
