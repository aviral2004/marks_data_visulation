# %%
# import csv file in pandas
import matplotlib.pyplot as plt
import pandas as pd
from scipy import stats
df = pd.read_csv('./data/CP/labtest1_final.csv')
# df['Marks'] = df['Marks'].fillna(0).astype(float)
#rename total column to marks
df.rename(columns={'Total':'Marks'}, inplace=True)
# add column with middle 2 digits of id
df['code'] = df['ID No'].str[4:6]

df
# Out:
#              ID No                       Name  Room     Set    Q1    Q2    Q3  \
# 0    2022A1PS0530P                  IRA DOGRA  6114    PINK   0.0   5.0  10.0
# 1    2022A1PS0589P            ASLESH JAMBHALE  6114    PINK   2.0  30.0  25.0
# 2    2022A1PS0593P  AAYUSH AASHISH MAHESHWARI  6114    PINK  14.0   5.0   2.0
# 3    2022A1PS0643P              SHIVANG GUPTA  6114    PINK  20.0  30.0  25.0
# 4    2022A1PS0661P              ARYAMAN DUBEY  6114    PINK   0.0   0.0   4.0
# ..             ...                        ...   ...     ...   ...   ...   ...
# 579  2022AAPS0360P             SPARSH JHANWAR  6017  Yellow  10.0   0.0   5.0
# 580  2022AAPS0363P             NISHKARSH JAIN  6017  Yellow  20.0  35.0  18.0
# 581  2022AAPS0366P             DIWAKAR MITTAL  6017  Yellow  20.0  35.0  10.0
# 582  2022AAPS0369P                 SUBRAT ROY  6017  Yellow  15.0   4.0   5.0
# 583  2022AAPS1191P     SHAILENDRA KUMAR GUPTA  6017  Yellow  16.0   8.0   7.0
#
#      Marks code
# 0       15   A1
# 1       57   A1
# 2       21   A1
# 3       75   A1
# 4        4   A1
# ..     ...  ...
# 579     15   AA
# 580     73   AA
# 581     65   AA
# 582     24   AA
# 583     31   AA
#
# [584 rows x 9 columns]

# %%
import seaborn as sns
sns.set_theme()

df.hist(column='Marks',bins=75)
plt.xlabel('Marks')
plt.ylabel('Frequency')
plt.title('Marks Distribution for CP Lab Test 1')
# Out:
# Text(0.5, 1.0, 'Marks Distribution for CP Lab Test 1')

# %%
print(df['Marks'].mean())
print(df['Marks'].median())
print(df['Marks'].mode())
# Out:
# 39.996649916247904
# 36.0
# 0    75
# Name: Marks, dtype: int64

# %%
from scipy import stats

for i in range(38, 76):
    print(f"marks: {i} -> {stats.percentileofscore(df['Marks'], i, kind='weak')}")
# Out:
# marks: 38 -> 52.42881072026801
# marks: 39 -> 52.93132328308208
# marks: 40 -> 53.936348408710224
# marks: 41 -> 54.103852596314916
# marks: 42 -> 54.773869346733676
# marks: 43 -> 55.10887772194305
# marks: 44 -> 55.10887772194305
# marks: 45 -> 56.616415410385265
# marks: 46 -> 57.118927973199334
# marks: 47 -> 57.6214405360134
# marks: 48 -> 58.458961474036855
# marks: 49 -> 59.63149078726968
# marks: 50 -> 59.96649916247907
# marks: 51 -> 60.80402010050252
# marks: 52 -> 61.30653266331659
# marks: 53 -> 61.97654941373535
# marks: 54 -> 62.47906197654942
# marks: 55 -> 63.31658291457287
# marks: 56 -> 63.651591289782246
# marks: 57 -> 63.98659966499163
# marks: 58 -> 64.32160804020101
# marks: 59 -> 64.82412060301507
# marks: 60 -> 66.66666666666667
# marks: 61 -> 67.67169179229481
# marks: 62 -> 69.17922948073702
# marks: 63 -> 70.51926298157454
# marks: 64 -> 70.85427135678393
# marks: 65 -> 74.03685092127304
# marks: 66 -> 74.03685092127304
# marks: 67 -> 75.54438860971526
# marks: 68 -> 75.71189279731993
# marks: 69 -> 78.89447236180905
# marks: 70 -> 79.7319932998325
# marks: 71 -> 80.06700167504188
# marks: 72 -> 80.06700167504188
# marks: 73 -> 82.91457286432161
# marks: 74 -> 82.91457286432161
# marks: 75 -> 100.00000000000001

# %%
fig, ax = plt.subplots(figsize = (6,4))
df['Marks'].plot(kind = "hist", density=True, bins=75)
df['Marks'].plot(kind = "kde", ax=ax)
ax.set_xlim(0, 75)
plt.show()

# %%
a7_df = df[df['code'] == 'A7']
a7_df
# Out:
#              ID No                       Name  Room     Set    Q1    Q2    Q3  \
# 310  2022A7PS0001P            KALPANA PANDA .  6017    PINK  14.0  30.0  25.0
# 311  2022A7PS0002P             SAANVI DANDE .  6017    PINK   NaN   NaN   NaN
# 312  2022A7PS0003P     SIDDARTH RAJAGOPALAN .  6017    PINK  20.0  30.0  25.0
# 313  2022A7PS0004P               DEEPAN ROY .  6017    PINK  20.0  30.0  25.0
# 314  2022A7PS0005P      DEVANSH NIKHIL SHAH .  6017    PINK   4.0   0.0   8.0
# ..             ...                        ...   ...     ...   ...   ...   ...
# 467  2022A7PS1186P             SHASHANK JHA .  6117  Yellow  20.0  35.0   7.0
# 468  2022A7PS1187P    HARSIMAR SINGH SALUJA .  6117  Yellow  20.0  35.0  20.0
# 469  2022A7PS1188P             ARMAAN SETHI .  6117  Yellow  20.0  35.0  20.0
# 470  2022A7PS1189P              ARNAV GUPTA .  6117  Yellow  20.0  30.0  10.0
# 471  2022A7PS1733P  PRATHAM PRATEEK MOHANTY .  6117  Yellow  18.0   0.0   0.0
#
#      Marks Unnamed: 8 code
# 310     69        NaN   A7
# 311      0     Absent   A7
# 312     75        NaN   A7
# 313     75        NaN   A7
# 314     12        NaN   A7
# ..     ...        ...  ...
# 467     62        NaN   A7
# 468     75        NaN   A7
# 469     75        NaN   A7
# 470     60        NaN   A7
# 471     18        NaN   A7
#
# [162 rows x 10 columns]

# %%
a7_df.hist(column='Marks',bins=75)
# Out:
# array([[<AxesSubplot:title={'center':'Marks'}>]], dtype=object)

# %%
for i in range(38, 75):
    print(f"marks: {i} -> {stats.percentileofscore(a7_df['Marks'], i, kind='weak')}")
# Out:
# marks: 38 -> 37.654320987654316
# marks: 39 -> 38.2716049382716
# marks: 40 -> 38.888888888888886
# marks: 41 -> 38.888888888888886
# marks: 42 -> 40.123456790123456
# marks: 43 -> 40.123456790123456
# marks: 44 -> 40.123456790123456
# marks: 45 -> 42.59259259259259
# marks: 46 -> 43.82716049382716
# marks: 47 -> 43.82716049382716
# marks: 48 -> 44.44444444444444
# marks: 49 -> 45.67901234567901
# marks: 50 -> 45.67901234567901
# marks: 51 -> 45.67901234567901
# marks: 52 -> 45.67901234567901
# marks: 53 -> 47.53086419753086
# marks: 54 -> 47.53086419753086
# marks: 55 -> 48.148148148148145
# marks: 56 -> 48.148148148148145
# marks: 57 -> 48.148148148148145
# marks: 58 -> 48.76543209876543
# marks: 59 -> 48.76543209876543
# marks: 60 -> 51.23456790123456
# marks: 61 -> 51.85185185185185
# marks: 62 -> 53.7037037037037
# marks: 63 -> 53.7037037037037
# marks: 64 -> 54.32098765432099
# marks: 65 -> 56.79012345679012
# marks: 66 -> 56.79012345679012
# marks: 67 -> 58.641975308641975
# marks: 68 -> 59.25925925925925
# marks: 69 -> 62.34567901234568
# marks: 70 -> 64.81481481481481
# marks: 71 -> 65.4320987654321
# marks: 72 -> 65.4320987654321
# marks: 73 -> 70.37037037037037
# marks: 74 -> 70.37037037037037

# %%
print(a7_df['Marks'].mean())
print(a7_df['Marks'].median())
# Out:
# 47.91358024691358
# 60.0

# %%
fig, ax = plt.subplots(figsize = (6,4))
df['Marks'].plot(kind = "hist", bins=75)
a7_df['Marks'].plot(kind = "hist", bins=75)
df[df['code'] == 'AA']['Marks'].plot(kind = "hist", bins=75, range=[0,75])
ax.set_xlim(0, 75)
plt.show()

# %%
fig, ax = plt.subplots(figsize = (6,4))
df['Marks'].plot(kind = "hist", bins=75)
df[df['Set'] == 'PINK']['Marks'].plot(kind = "hist", bins=75)
# df[df['Set'] == 'ORANGE']['Marks'].plot(kind = "hist", bins=75)
# df[df['code'] == 'AA']['Marks'].plot(kind = "hist", bins=75, range=[0,75])
ax.set_xlim(0, 75)
plt.show()

# %%
pivot = df.pivot_table(index="ID No", columns='code', values='Marks')
pivot.plot(kind='box', figsize=(10, 7))
# Out:
# <AxesSubplot:>

# %%
import matplotlib.ticker as ticker

fig, ax = plt.subplots(figsize = (10,4))
fun = lambda k: [i/k for i in list(range(1, 75*k + 1))]

a = fun(2)
b = [stats.percentileofscore(df["Marks"],i, kind='weak') for i in a]
ax.plot(a, b)

lis = [i for i in range(0, 101)]

plt.axvline(x=df['Marks'].quantile([0.5]).values[0], color='pink', linestyle='--', label='50th percentile')
plt.axvline(x=df['Marks'].quantile([0.9]).values[0], color='red', linestyle='--', label='90th percentile')
plt.axvline(x=df['Marks'].quantile([0.75]).values[0], color='green', linestyle='--', label='75th percentile')
plt.axvline(x=df['Marks'].quantile([0.8]).values[0], color='yellow', linestyle='--', label='80th percentile')



ax.xaxis.set_major_locator(ticker.MultipleLocator(5))
ax.set_ylim(0,101)
ax.set_xlim(0,75)
ax.set_xlabel("Marks")
ax.set_ylabel("Percentile")
ax.legend()
plt.show()
