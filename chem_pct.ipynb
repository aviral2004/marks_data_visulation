# %%
import matplotlib.pyplot as plt
import pandas as pd
from scipy import stats

import seaborn as sns
sns.set_theme()

df = pd.read_csv('./data/chem_pct.csv')

df.rename(columns={'PCT':'Marks'}, inplace=True)
df.rename(columns={'ID NO':'ID'}, inplace=True)

# %load_ext autoreload
# %autoreload 2

df
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
#                 ID                       Name    Q1    Q2    Q3    Q4  Best 3  \
# 0    2022A1PS0530P                  IRA DOGRA  21.5  13.0   5.5  14.5    49.0
# 1    2022A1PS0589P            ASLESH JAMBHALE  25.0  21.5  22.0  15.0    68.5
# 2    2022A1PS0593P  AAYUSH AASHISH MAHESHWARI  25.0  16.5  19.0   9.0    60.5
# 3    2022A1PS0643P              SHIVANG GUPTA  19.5  17.5  12.0  15.5    52.5
# 4    2022A1PS0661P              ARYAMAN DUBEY   0.0   0.0   4.5   2.5     7.0
# ..             ...                        ...   ...   ...   ...   ...     ...
# 576  2022AAPS0363P             NISHKARSH JAIN  20.0  13.0  20.5   9.0    53.5
# 577  2022AAPS0366P             DIWAKAR MITTAL  25.5  25.5  18.0  15.5    69.0
# 578  2022AAPS0369P                 SUBRAT ROY  21.5  22.0  13.0  14.0    57.5
# 579  2022AAPS1191P     SHAILENDRA KUMAR GUPTA  22.5  14.0  19.0  12.5    55.5
# 580  2022AAPS1192P            KUSHAAGRA SINGH  27.0  13.0  15.5  18.0    60.5
#
#      Midsem  Marks
# 0      21.5   70.5
# 1      37.5  106.0
# 2      37.0   97.5
# 3      24.5   77.0
# 4      11.5   18.5
# ..      ...    ...
# 576    34.0   87.5
# 577    40.0  109.0
# 578    26.0   83.5
# 579    32.5   88.0
# 580    44.5  105.0
#
# [581 rows x 9 columns]

# %%
from graph_gen import graph

g = graph('GenChem PCT', df, 180)
g.gen_all()
